# %%
import numpy as np
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Admin\\3D Objects\\imarticus PGDA\\Machine learning\\NEW DATASET\\Hackathon\\Bigmart Sales'

# %%
df_train=pd.read_csv('train.csv')
df_test=pd.read_csv('test.csv')
df_1=df_train.copy(deep=True)
df_2=df_test.copy(deep=True)
df_1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
nulls=df_1.isnull().sum()
df_null=pd.DataFrame({'count':nulls,'percent':((nulls/df_1.shape[0])*100)})
df_null=df_null.sort_values('percent',ascending =False)
df_null
# Out:
#                            count    percent
# Outlet_Size                 2410  28.276428
# Item_Weight                 1463  17.165317
# Item_Identifier                0   0.000000
# Item_Fat_Content               0   0.000000
# Item_Visibility                0   0.000000
# Item_Type                      0   0.000000
# Item_MRP                       0   0.000000
# Outlet_Identifier              0   0.000000
# Outlet_Establishment_Year      0   0.000000
# Outlet_Location_Type           0   0.000000
# Outlet_Type                    0   0.000000
# Item_Outlet_Sales              0   0.000000

# %%
df_o=pd.concat([df_train,df_test],axis=1)
df_o
# Out:
#      Item_Identifier Item_Weight  Item_Fat_Content Item_Visibility  \
# 0              FDA15       9.300           Low Fat        0.016047
# 1              DRC01       5.920           Regular        0.019278
# 2              FDN15      17.500           Low Fat        0.016760
# 3              FDX07      19.200           Regular        0.000000
# 4              NCD19       8.930           Low Fat        0.000000
# ...              ...         ...               ...             ...
# 8518           FDF22       6.865           Low Fat        0.056783
# 8519           FDS36       8.380           Regular        0.046982
# 8520           NCJ29      10.600           Low Fat        0.035186
# 8521           FDN46       7.210           Regular        0.145221
# 8522           DRG01      14.800           Low Fat        0.044878
#
#                   Item_Type  Item_MRP  Outlet_Identifier  \
# 0                     Dairy  249.8092             OUT049
# ...

# %%
df_o.Item_Type.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13068/2494195029.py in <module>
# ----> 1 df_o.Item_Type.unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
nulls=df_o.isnull().sum()
df_null=pd.DataFrame({'count':nulls,'percent':((nulls/df_o.shape[0])*100)})
df_null=df_null.sort_values('percent',ascending =False)
df_null
# Out:
#                            count    percent
# Outlet_Size                 4448  52.188197
# Item_Weight                 3818  44.796433
# Outlet_Type                 2842  33.345066
# Outlet_Location_Type        2842  33.345066
# Outlet_Establishment_Year   2842  33.345066
# Outlet_Identifier           2842  33.345066
# Item_MRP                    2842  33.345066
# Item_Type                   2842  33.345066
# Item_Visibility             2842  33.345066
# Item_Fat_Content            2842  33.345066
# Item_Identifier             2842  33.345066
# Outlet_Size                 2410  28.276428
# Item_Weight                 1463  17.165317
# Item_Identifier                0   0.000000
# Outlet_Type                    0   0.000000
# Outlet_Location_Type           0   0.000000
# Outlet_Establishment_Year      0   0.000000
# Outlet_Identifier              0   0.000000
# Item_MRP                       0   0.000000
# Item_Type                      0   0.000000
# ...

# %%
df_1.Outlet_Size.unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
df_1.Outlet_Size.value_counts()
# Out:
# Medium    5203
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df_1.Outlet_Size.unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
df_o.Item_Identifier.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13068/868768204.py in <module>
# ----> 1 df_o.Item_Identifier.unique()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df_1.Outlet_Size.value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
df_1.Outlet_Size.fillna('Medium',inplace=True)

# %%
df_1.Outlet_Size
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64
