# %%
import pandas as pd
import numpy as np
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Dhananjay\\Documents\\PGDA Data Science\\imarticus PGDA\\Machine learning\\Supervised Learning\\Linear Regression\\House Price'

# %%
pd.set_option("display.max_columns",None)

# %%
hp =pd.read_csv("HousePrices.csv")
hp
# Out:
#        Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0       1          60         RL         65.0     8450      Pave   NaN
# 1       2          20         RL         80.0     9600      Pave   NaN
# 2       3          60         RL         68.0    11250      Pave   NaN
# 3       4          70         RL         60.0     9550      Pave   NaN
# 4       5          60         RL         84.0    14260      Pave   NaN
# ...   ...         ...        ...          ...      ...       ...   ...
# 2068  942          60         RL          NaN     8755      Pave   NaN
# 2069  943          90         RL         63.0     7711      Pave   NaN
# 2070  944          90         RL        313.0    25000      Pave   NaN
# 2071  945          20         RL         52.0    14375      Pave   NaN
# 2072  946          50         RM         98.0     8820      Pave   NaN
#
#      Property_Shape LandContour Utilities LotConfig LandSlope Neighborhood  \
# ...

# %%
hp.columns
# Out:
# Index(['Id', 'Dwell_Type', 'Zone_Class', 'LotFrontage', 'LotArea', 'Road_Type',
#        'Alley', 'Property_Shape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'Dwelling_Type', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
hp.isnull().sum()
# Out:
# Id                       0
# Dwell_Type               0
# Zone_Class               0
# LotFrontage            320
# LotArea                  0
#                       ...
# MoSold                   0
# YrSold                   0
# SaleType                 0
# SaleCondition            0
# Property_Sale_Price      0
# Length: 81, dtype: int64

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score

# %%
hp.columns
# Out:
# Index(['Id', 'Dwell_Type', 'Zone_Class', 'LotFrontage', 'LotArea', 'Road_Type',
#        'Alley', 'Property_Shape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'Dwelling_Type', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
pd.options.display.max_columns =None

# %%
hp.drop("Id",axis=1,inplace =True)

# %%
hp
# Out:
#       Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0             60         RL         65.0     8450      Pave   NaN
# 1             20         RL         80.0     9600      Pave   NaN
# 2             60         RL         68.0    11250      Pave   NaN
# 3             70         RL         60.0     9550      Pave   NaN
# 4             60         RL         84.0    14260      Pave   NaN
# ...          ...        ...          ...      ...       ...   ...
# 2068          60         RL          NaN     8755      Pave   NaN
# 2069          90         RL         63.0     7711      Pave   NaN
# 2070          90         RL        313.0    25000      Pave   NaN
# 2071          20         RL         52.0    14375      Pave   NaN
# 2072          50         RM         98.0     8820      Pave   NaN
#
#      Property_Shape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 0               Reg         Lvl    AllPub    Inside       Gtl      CollgCr
# ...

# %%
nullcols =hp.isnull().sum()
type(nullcols)
nullcols
# Out:
# Dwell_Type               0
# Zone_Class               0
# LotFrontage            320
# LotArea                  0
# Road_Type                0
#                       ...
# MoSold                   0
# YrSold                   0
# SaleType                 0
# SaleCondition            0
# Property_Sale_Price      0
# Length: 80, dtype: int64

# %%
nullcols[nullcols>0]
# Out:
# LotFrontage      320
# Alley           1944
# MasVnrType        14
# MasVnrArea        14
# BsmtQual          59
# BsmtCond          59
# BsmtExposure      61
# BsmtFinType1      59
# BsmtFinType2      60
# Electrical         1
# FireplaceQu      988
# GarageType       113
# GarageYrBlt      113
# GarageFinish     113
# GarageQual       113
# GarageCond       113
# PoolQC          2065
# Fence           1669
# MiscFeature     1993
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
nullcols = hp.isnull().sum()
plt.figure(figsize =(15,5))
nullcols = nullcols[nullcols>0]
nullcols.sort_values(ascending =False,inplace =True)
nullcols.plot(kind ="bar")
plt.show()

# %%
null_cols=hp.isnull().sum()
null_cols
# Out:
# Dwell_Type               0
# Zone_Class               0
# LotFrontage            320
# LotArea                  0
# Road_Type                0
#                       ...
# MoSold                   0
# YrSold                   0
# SaleType                 0
# SaleCondition            0
# Property_Sale_Price      0
# Length: 80, dtype: int64

# %%
hp.Dwell_Type.value_counts()
# Out:
# 20      722
# 60      431
# 50      205
# 30      133
# 120     114
# 90       91
# 80       78
# 160      78
# 70       77
# 190      42
# 85       34
# 75       19
# 180      14
# 45       13
# 150      13
# 40        7
# 303       1
# 7080      1
# Name: Dwell_Type, dtype: int64

# %%
null_cols =hp.isnull().sum()
null_cols
# Out:
# Dwell_Type               0
# Zone_Class               0
# LotFrontage            320
# LotArea                  0
# Road_Type                0
#                       ...
# MoSold                   0
# YrSold                   0
# SaleType                 0
# SaleCondition            0
# Property_Sale_Price      0
# Length: 80, dtype: int64

# %%
hp.LotFrontage.fillna(hp.LotFrontage.median(),inplace =True)

# %%
hp.MasVnrArea.fillna(hp.MasVnrArea.median(),inplace = True)
hp.GarageYrBlt.fillna(hp.GarageYrBlt.median(),inplace = True)
#or

# %%
hp
# Out:
#       Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0             60         RL         65.0     8450      Pave   NaN
# 1             20         RL         80.0     9600      Pave   NaN
# 2             60         RL         68.0    11250      Pave   NaN
# 3             70         RL         60.0     9550      Pave   NaN
# 4             60         RL         84.0    14260      Pave   NaN
# ...          ...        ...          ...      ...       ...   ...
# 2068          60         RL         70.0     8755      Pave   NaN
# 2069          90         RL         63.0     7711      Pave   NaN
# 2070          90         RL        313.0    25000      Pave   NaN
# 2071          20         RL         52.0    14375      Pave   NaN
# 2072          50         RM         98.0     8820      Pave   NaN
#
#      Property_Shape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 0               Reg         Lvl    AllPub    Inside       Gtl      CollgCr
# ...

# %%
hp.GarageYrblt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 hp.GarageYrblt
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'GarageYrblt'

# %%
num_types= hp.select_dtypes(include= [np.number])
num_types

# %%
hp

# %%
numeric_cols =hp.select_dtypes(include =[np.number])
numeric_cols
# Out:
#       Dwell_Type  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0     8450            7            5       2003
# 1             20         80.0     9600            6            8       1976
# 2             60         68.0    11250            7            5       2001
# 3             70         60.0     9550            7            5       1915
# 4             60         84.0    14260            8            5       2000
# ...          ...          ...      ...          ...          ...        ...
# 2068          60         70.0     8755            8            4       1936
# 2069          90         63.0     7711            6            9       1936
# 2070          90        313.0    25000            4            6       1983
# 2071          20         52.0    14375            9            6       1958
# 2072          50         98.0     8820            9            9       1890
#
# ...

# %%
hp.LotFrontage.median()

# %%
object_types =hp.select_dtypes(include =object)
object_types
# Out:
#      Zone_Class Road_Type Alley Property_Shape LandContour Utilities  \
# 0            RL      Pave   NaN            Reg         Lvl    AllPub
# 1            RL      Pave   NaN            Reg         Lvl    AllPub
# 2            RL      Pave   NaN            IR1         Lvl    AllPub
# 3            RL      Pave   NaN            IR1         Lvl    AllPub
# 4            RL      Pave   NaN            IR1         Lvl    AllPub
# ...         ...       ...   ...            ...         ...       ...
# 2068         RL      Pave   NaN            IR1         Lvl    AllPub
# 2069         RL      Pave   NaN            IR1         Lvl    AllPub
# 2070         RL      Pave   NaN            Reg         Low    AllPub
# 2071         RL      Pave   NaN            IR1         Lvl    NoSeWa
# 2072         RM      Pave   NaN            Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood Condition1 Condition2 Dwelling_Type  \
# ...

# %%
object_types=object_types.astype("category")

# %%
object_types.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 43 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Zone_Class      2073 non-null   object
#  1   Road_Type       2073 non-null   object
#  2   Alley           129 non-null    object
#  3   Property_Shape  2073 non-null   object
#  4   LandContour     2073 non-null   object
#  5   Utilities       2073 non-null   object
#  6   LotConfig       2073 non-null   object
#  7   LandSlope       2073 non-null   object
#  8   Neighborhood    2073 non-null   object
#  9   Condition1      2073 non-null   object
#  10  Condition2      2073 non-null   object
#  11  Dwelling_Type   2073 non-null   object
#  12  HouseStyle      2073 non-null   object
#  13  RoofStyle       2073 non-null   object
#  14  RoofMatl        2073 non-null   object
#  15  Exterior1st     2073 non-null   object
#  16  Exterior2nd     2073 non-null   object
# ...

# %%
null_object =object_types.isnull().sum()
null_object[null_object>0]
# Out:
# Alley           1944
# MasVnrType        14
# BsmtQual          59
# BsmtCond          59
# BsmtExposure      61
# BsmtFinType1      59
# BsmtFinType2      60
# Electrical         1
# FireplaceQu      988
# GarageType       113
# GarageFinish     113
# GarageQual       113
# GarageCond       113
# PoolQC          2065
# Fence           1669
# MiscFeature     1993
# dtype: int64

# %%
#Displaying null value in object type columns
import seaborn as sns
null_object =object_types.isnull().sum()
plt.figure(figsize =(15,5))
null_object =null_object[null_object>0]
null_object.sort_values(ascending =False,inplace = True)
null_object.plot(kind ="bar")
plt.show()

# %%
null_object =object_types.isnull().sum()
null_object[null_object>0]
# Out:
# Alley           1944
# MasVnrType        14
# BsmtQual          59
# BsmtCond          59
# BsmtExposure      61
# BsmtFinType1      59
# BsmtFinType2      60
# Electrical         1
# FireplaceQu      988
# GarageType       113
# GarageFinish     113
# GarageQual       113
# GarageCond       113
# PoolQC          2065
# Fence           1669
# MiscFeature     1993
# dtype: int64

# %%
from scipy.stats import f_oneway

# %%
numeric_cols.columns[:]
# Out:
# Index(['Dwell_Type', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'Property_Sale_Price'],
#       dtype='object')

# %%
object_types.columns
# Out:
# Index(['Zone_Class', 'Road_Type', 'Alley', 'Property_Shape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'Dwelling_Type', 'HouseStyle', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC',
#        'Fence', 'MiscFeature', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
null_object =object_types.isnull().sum()
null_object[null_object>0]
# Out:
# Alley           1944
# MasVnrType        14
# BsmtQual          59
# BsmtCond          59
# BsmtExposure      61
# BsmtFinType1      59
# BsmtFinType2      60
# Electrical         1
# FireplaceQu      988
# GarageType       113
# GarageFinish     113
# GarageQual       113
# GarageCond       113
# PoolQC          2065
# Fence           1669
# MiscFeature     1993
# dtype: int64

# %%
hp.Alley.fillna("none")
# Out:
# 0       none
# 1       none
# 2       none
# 3       none
# 4       none
#         ...
# 2068    none
# 2069    none
# 2070    none
# 2071    none
# 2072    none
# Name: Alley, Length: 2073, dtype: object

# %%
object_types=object_types.astype("object")

# %%
object_types.fillna("none",inplace =True)

# %%
object_types
# Out:
#      Zone_Class Road_Type Alley Property_Shape LandContour Utilities  \
# 0            RL      Pave  none            Reg         Lvl    AllPub
# 1            RL      Pave  none            Reg         Lvl    AllPub
# 2            RL      Pave  none            IR1         Lvl    AllPub
# 3            RL      Pave  none            IR1         Lvl    AllPub
# 4            RL      Pave  none            IR1         Lvl    AllPub
# ...         ...       ...   ...            ...         ...       ...
# 2068         RL      Pave  none            IR1         Lvl    AllPub
# 2069         RL      Pave  none            IR1         Lvl    AllPub
# 2070         RL      Pave  none            Reg         Low    AllPub
# 2071         RL      Pave  none            IR1         Lvl    NoSeWa
# 2072         RM      Pave  none            Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood Condition1 Condition2 Dwelling_Type  \
# ...

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, accuracy_score

# %%
model =LinearRegression()

# %%
hp.columns
# Out:
# Index(['Dwell_Type', 'Zone_Class', 'LotFrontage', 'LotArea', 'Road_Type',
#        'Alley', 'Property_Shape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'Dwelling_Type', 'HouseStyle', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF',
#        '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
#        'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %%
import statsmodels.api as sm
model =LinearRegression()

# %%
x =numeric_cols.drop('Property_Sale_Price',axis=1)

# %%
x=numeric_cols

# %%
y =numeric_cols['Property_Sale_Price']
y
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 2068    214000
# 2069    150000
# 2070    143000
# 2071    137500
# 2072    124900
# Name: Property_Sale_Price, Length: 2073, dtype: int64

# %%
numeric_cols.MasVnrArea.fillna(hp.MasVnrArea.median(),inplace = True)
numeric_cols.GarageYrBlt.fillna(hp.GarageYrBlt.median(),inplace = True)
numeric_cols.LotFrontage.fillna(hp.LotFrontage.median(),inplace = True)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state =100)

# %% [markdown]
# ## Linear Regression Basic Model

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
numeric_cols.isnull().sum()
# Out:
# Dwell_Type             0
# LotFrontage            0
# LotArea                0
# OverallQual            0
# OverallCond            0
# YearBuilt              0
# YearRemodAdd           0
# MasVnrArea             0
# BsmtFinSF1             0
# BsmtFinSF2             0
# BsmtUnfSF              0
# TotalBsmtSF            0
# 1stFlrSF               0
# 2ndFlrSF               0
# LowQualFinSF           0
# GrLivArea              0
# BsmtFullBath           0
# BsmtHalfBath           0
# FullBath               0
# HalfBath               0
# BedroomAbvGr           0
# KitchenAbvGr           0
# TotRmsAbvGrd           0
# Fireplaces             0
# GarageYrBlt            0
# GarageCars             0
# GarageArea             0
# WoodDeckSF             0
# OpenPorchSF            0
# EnclosedPorch          0
# 3SsnPorch              0
# ScreenPorch            0
# PoolArea               0
# MiscVal                0
# MoSold                 0
# YrSold                 0
# Property_Sale_Price    0
# ...

# %%
price_predict_y =model.predict(x_test)
print(price_predict_y)
price_predict_y.shape
# Out:
# [160000. 208900. 200000. 177500. 114500. 112000. 235128. 160000. 120500.
#  266500. 222000. 230000.  81000. 149300. 200624. 154500. 112500. 174900.
#  140000. 116500. 142125. 162000. 158000. 205000. 177000.  88000. 110000.
#  175000. 159895. 320000. 192140. 164000. 236500. 170000. 143000. 129900.
#  112000. 136900. 206900. 132000. 315000. 144000. 160000. 160000.  92000.
#  148800. 115000. 155000. 115000. 124000. 125000. 149500. 369900. 275000.
#   91500. 340000. 271000.  91000. 278000. 220000. 115000. 168500.  85500.
#  253293. 145000. 242000. 214000. 175000. 252000. 140000. 143000. 177500.
#  140000. 130250. 153000.  92000. 180500. 170000. 394617. 172500. 238000.
#  306000. 266500. 207000. 378500. 179600. 315500. 133000.  66500. 117500.
#  160000. 133900. 173000. 138000. 117000. 144500.  85000.  82000. 197000.
#  112000. 140000.  80000. 174000. 141000. 286000. 168500. 144000. 239000.
#  167900. 145000. 169000. 199900. 211000. 173733. 131000. 163000. 200000.
# ...

# %%
from sklearn.metrics import r2_score

# %%
mss=mean_squared_error(y_test,price_predict_y)
print("mean_squared_error is",mss)
print("Root mean_squared_error is",np.sqrt(mss)) 

print('R2_score',r2_score(y_test,price_predict_y))
# Out:
# mean_squared_error is 4.910101560199014e-22
# Root mean_squared_error is 2.2158748972356302e-11
# R2_score 1.0
