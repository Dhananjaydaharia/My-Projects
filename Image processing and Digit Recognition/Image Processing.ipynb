# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
import os

# %%
def show_image( image,title='Image',cmap_type='gray'):
    plt.imshow(image,cmap=cmap_type)
    plt.title(title)
    plt.axis('off')
    plt.show()

# %%
# Import modules from skinage
from skimage import  data,color

# Load the rocket image
rocket =data.rocket()


#show the original Image
show_image(rocket,'Original RGB Image')

# %%
#convert rgb to grayscale
gray_scaled_rocket =color.rgb2gray(rocket)

#show the original Image
show_image(gray_scaled_rocket,'Original RGB Image')

# %%
#RED color
red_rocket=rocket[:,:,2]

#show the original Image
show_image(red_rocket,'Original RGB Image')

# %%
#green color
green_rocket=rocket[:,:,1]

#show the original Image
show_image(green_rocket,'Original RGB Image')

# %%
#green color
blue_rocket=rocket[:,:,0]

#show the original Image
show_image(blue_rocket,'Original RGB Image')

# %%
# flip image
flip_rocket=np.flipud(rocket)

#show the original Image
show_image(flip_rocket,'Original RGB Image')

# %%
# flip the image Left and right

# flip image
LRflip_rocket=np.fliplr(rocket)

#show the original Image
show_image(LRflip_rocket,'Original RGB Image')

# %%
#
plt.hist()

# %%
#read image
src = cv2.imread('D:/cv2-resize-image-original.png', cv2.IMREAD_UNCHANGED)
print(src.shape)
